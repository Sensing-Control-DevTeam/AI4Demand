# %% [markdown]
# # Data request through API

# %% [markdown]
# ### This is a small Python code for the collection of daily and hourly electricity consumption, heating, water and cooling datasets from the city of Helsinki buildings database

# %%
# Import necessary libraries
from matplotlib import pyplot as plt
import warnings
import requests
import json
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import concurrent.futures
import time
from functools import partial
from datetime import datetime
import os

# %%
response = requests.get('https://helsinki-openapi.nuuka.cloud/api/v1.0/Property/List').text

# %%
# Get the list of all available buildings
response
# Out:
# '[{"locationName":"1000 Hakaniemen kauppahalli","propertyName":"1000 Hakaniemen kauppahalli","propertyCode":"091-011-9902-0101"},{"locationName":"1001 Hietalahden kauppahalli","propertyName":"1001 Hietalahden kauppahalli","propertyCode":"091-004-9902-0008"},{"locationName":"1002 Vanha kauppahalli","propertyName":"1002 Vanha kauppahalli","propertyCode":"091-003-9906-0101"},{"locationName":"1037 Vuotalo","propertyName":"1037 Vuotalo","propertyCode":"091-054-0179-0003"},{"locationName":"1507 Suutarilan monitoimitalo/ala-aste ja Lpk Seulanen","propertyName":"1507 Suutarilan monitoimitalo/ala-aste ja Lpk Seulanen","propertyCode":"091-040-0024-0003"},{"locationName":"1508 Monitoimitalo Puustelli","propertyName":"1508 Monitoimitalo Puustelli","propertyCode":"091-033-0232-0003, 091-033-0260-0001"},{"locationName":"1509 Lpk Karvikka ja rppk Lemmikki","propertyName":"1509 Lpk Karvikka ja rppk Lemmikki","propertyCode":"091-038-0055-0010"},{"locationName":"1511 Pauligin huvila","propertyName":"1511 Pauligin huvila","propertyCode":"091-014-9903-0102"},{"locationName":"1512 Malmin raitti 3","propertyName":"1512 Malmin raitti 3","propertyCode":"091-038-0107-0016"},{"locationName":"1513 Psykiatrinen poliklinikka","propertyName":"1513 Psykiatrinen poliklinikka","propertyCode":"091-022-0548-0043"},{"locationName":"1515 Myllypuron peruskoulu/Lpk Neulanen/Neulapadont. 6","propertyName":"1515 Myllypuron peruskoulu/Lpk Neulanen/Neulapadont. 6","propertyCode":"091-045-0138-0003"},{"locationName":"1521 Harjun NT (disabled)","propertyName":"1521 Harjun NT","propertyCode":"091-022-0366-0001"},{"locationName":"1526 Annantalo","propertyName":"1526 Annantalo","propertyCode":"091-004-0001-0012"},{"locationName":"1527 Koskelan NT","propertyName":"1527 Koskelan NT","propertyCode":"091-026-0975-0005"},{"locationName":"1528 Apollon yhteiskoulu","propertyName":"1528 Apollon yhteiskoulu","propertyCode":"091-033-0232-0002"},{"locationName":"1540 Virastotalo, Dagmarinkatu 6 (disabled)","propertyName":"1540 Virastotalo, Dagmarinkatu 6","propertyCode":"091-013-0407-0010"},{"locationName":"1544 Lpk Linnunlaulu ja Lpk Arla","propertyName":"1544 Lpk Linnunlaulu ja Lpk Arla","propertyCode":"091-011-9903-0111"},{"locationName":"1546 Koulutuskeskus","propertyName":"1546 Koulutuskeskus","propertyCode":"091-011-0302-0007, 091-011-0302-0008"},{"locationName":"1550 Fallkullan kartano/Kotieläintila","propertyName":"1550 Fallkullan kartano/Kotieläintila","propertyCode":"091-429-0001-0479, 091-429-0005-0270"},{"locationName":"1556 Harakan luontokeskus","propertyName":"1556 Harakan luontokeskus","propertyCode":"091-432-0002-0000"},{"locationName":"1561 Työterveyskeskus","propertyName":"1561 Työterveyskeskus","propertyCode":"091-011-0326-0024"},{"locationName":"1575 Nuorisoasiainkeskus, Lpk Leppäsuo","propertyName":"1575 Nuorisoasiainkeskus, Lpk Leppäsuo","propertyCode":"091-013-0434-0002"},{"locationName":"1580 Kruununmakasiini","propertyName":"1580 Kruununmakasiini","propertyCode":"091-410-0001-0004"},{"locationName":"1591 Etelä-Haagan kirjasto, NT","propertyName":"1591 Etelä-Haagan kirjasto, NT","propertyCode":"091-029-0006-0004"},{"locationName":"1597 Lpk Lauttasaaren Ankkalampi (disabloitu)","propertyName":"1597 Lpk Lauttasaaren Ankkalampi","propertyCode":"091-414-0001-0618"},{"locationName":"1598 Jakomäen kirjasto","propertyName":"1598 Jakomäen kirjasto","propertyCode":"091-041-0200-0010"},{"locationName":"1603 Korttelitalo Merirasti","propertyName":"1603 Korttelitalo Merirasti","propertyCode":"091-054-0222-0002"},{"locationName":"1608 Koskelan ala-aste /Lpk Herttua","propertyName":"1608 Koskelan ala-aste /Lpk Herttua","propertyCode":"091-026-0973-0003"},{"locationName":"1610 Laakavuoren korttelitalo/a-a/Lpk","propertyName":"1610 Laakavuoren korttelitalo/a-a/Lpk","propertyCode":"091-047-0330-0001"},{"locationName":"1620 Tulli- ja pakkahuone, K 11","propertyName":"1620 Tulli- ja pakkahuone, K 11","propertyCode":"091-008-0184-0006"},{"locationName":"1621 Ravintola Kappeli ja l ...

# %%
response_info = json.loads(response)

# %% [raw]
# response_info

# %%
type(response_info)
# Out:
# list

# %%
### An example of request of a daily data for a specific building

requests.get('https://helsinki-openapi.nuuka.cloud/api/v1/EnergyData/Daily/ListByProperty?Record=LocationName&SearchString=4285%20Kaisaniemen%20ala-aste&ReportingGroup=Electricity&StartTime=2019-01-01&EndTime=2021-12-31').json()
# Out:
# [{'timestamp': '2019-01-01T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 799.8599999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-01-02T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 787.14,
#   'unit': 'kWh'},
#  {'timestamp': '2019-01-03T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 696.9099999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-01-04T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 789.18,
#   'unit': 'kWh'},
#  {'timestamp': '2019-01-05T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 677.54,
#   'unit': 'kWh'},
#  {'timestamp': '2019-01-06T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 687.8899999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-01-07T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1064.7899999999997,
#   'unit': 'kWh'},
#  {'timestamp': '2019-01-08T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1092.52,
#   'unit': 'kWh'},
#  {'timestamp': '2019-01-09T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1002.5400000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-01-10T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 999.3800000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2019-01-11T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 995.4799999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-01-12T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 667.6,
#   'unit': 'kWh'},
#  {'timestamp': '2019-01-13T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 667.7900000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-01-14T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 998.24,
#   'unit': 'kWh'},
#  {'timestamp': '2019-01-15T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 984.9900000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2019-01-16T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 982.24,
#   'unit': 'kWh'},
#  {'timestamp': '2019-01-17T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 989.6099999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-01-21T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 956.2500000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-01-22T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 981.1900000000003,
#   'unit': 'kWh'},
#  {'timestamp': '2019-01-23T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 994.72,
#   'unit': 'kWh'},
#  {'timestamp': '2019-01-24T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 941.62,
#   'unit': 'kWh'},
#  {'timestamp': '2019-01-25T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 970.35,
#   'unit': 'kWh'},
#  {'timestamp': '2019-01-26T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 650.8400000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-01-27T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 644.29,
#   'unit': 'kWh'},
#  {'timestamp': '2019-01-28T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 982.8499999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-01-29T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 975.4,
#   'unit': 'kWh'},
#  {'timestamp': '2019-01-30T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 987.22,
#   'unit': 'kWh'},
#  {'timestamp': '2019-01-31T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 970.3999999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-02-01T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 969.85,
#   'unit': 'kWh'},
#  {'timestamp': '2019-02-02T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 659.6999999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-02-03T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 667.94,
#   'unit': 'kWh'},
#  {'timestamp': '2019-02-05T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 953.3899999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2019-02-06T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1007.79,
#   'unit': 'kWh'},
#  {'timestamp': '2019-02-07T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 849.9899999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-02-08T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 947.8699999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-02-09T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 670.4599999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-02-10T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 675.0999999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-02-11T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 984.5200000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2019-02-12T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 954.5400000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-02-13T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 984.6700000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-02-14T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 927.73,
#   'unit': 'kWh'},
#  {'timestamp': '2019-02-15T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 930.5799999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-02-16T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 668.72,
#   'unit': 'kWh'},
#  {'timestamp': '2019-02-17T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 663.4000000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-02-18T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 723.6699999999997,
#   'unit': 'kWh'},
#  {'timestamp': '2019-02-19T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 731.03,
#   'unit': 'kWh'},
#  {'timestamp': '2019-02-20T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 745.4999999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-02-21T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 721.6400000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-02-22T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 698.9700000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-02-23T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 655.98,
#   'unit': 'kWh'},
#  {'timestamp': '2019-02-24T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 659.7299999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-02-25T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 981.0100000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-02-26T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 966.3599999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-02-27T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 985.8999999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-02-28T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 963.6300000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-03-01T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 928.45,
#   'unit': 'kWh'},
#  {'timestamp': '2019-03-02T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 675.5,
#   'unit': 'kWh'},
#  {'timestamp': '2019-03-03T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 665.5000000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-03-04T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 982.19,
#   'unit': 'kWh'},
#  {'timestamp': '2019-03-05T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 956.66,
#   'unit': 'kWh'},
#  {'timestamp': '2019-03-06T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 983.63,
#   'unit': 'kWh'},
#  {'timestamp': '2019-03-07T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1004.76,
#   'unit': 'kWh'},
#  {'timestamp': '2019-03-08T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 969.5300000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2019-03-09T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 686.44,
#   'unit': 'kWh'},
#  {'timestamp': '2019-03-10T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 681.9499999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2019-03-11T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1028.04,
#   'unit': 'kWh'},
#  {'timestamp': '2019-03-12T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 991.05,
#   'unit': 'kWh'},
#  {'timestamp': '2019-03-13T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 954.7899999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2019-03-14T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 985.6500000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-03-15T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 955.3899999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2019-03-16T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 683.53,
#   'unit': 'kWh'},
#  {'timestamp': '2019-03-17T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 682.79,
#   'unit': 'kWh'},
#  {'timestamp': '2019-03-18T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 978.3600000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-03-19T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 975.61,
#   'unit': 'kWh'},
#  {'timestamp': '2019-03-20T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 973.5200000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2019-03-21T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 990.1300000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2019-03-22T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 969.53,
#   'unit': 'kWh'},
#  {'timestamp': '2019-03-23T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 698.9,
#   'unit': 'kWh'},
#  {'timestamp': '2019-03-24T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 697.6599999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-03-25T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1009.0799999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-03-26T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 971.8699999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-03-27T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 955.3299999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-03-28T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 991.0099999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2019-03-29T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 926.0300000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-03-30T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 754.25,
#   'unit': 'kWh'},
#  {'timestamp': '2019-03-31T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 720.6,
#   'unit': 'kWh'},
#  {'timestamp': '2019-04-01T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1027.6899999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2019-04-02T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1012.6200000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-04-03T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 965.7699999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-04-04T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 999.7800000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-04-05T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 967.58,
#   'unit': 'kWh'},
#  {'timestamp': '2019-04-06T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 737.8699999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-04-07T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 733.1100000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-04-08T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 985.0100000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-04-09T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 989.52,
#   'unit': 'kWh'},
#  {'timestamp': '2019-04-10T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 981.9399999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-04-11T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 997.14,
#   'unit': 'kWh'},
#  {'timestamp': '2019-04-12T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 953.7099999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2019-04-13T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 719.3999999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-04-14T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 753.0000000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-04-15T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 989.6800000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2019-04-16T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 997.4300000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-04-17T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 987.63,
#   'unit': 'kWh'},
#  {'timestamp': '2019-04-18T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1060.75,
#   'unit': 'kWh'},
#  {'timestamp': '2019-04-19T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 775.9799999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2019-04-20T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 747.72,
#   'unit': 'kWh'},
#  {'timestamp': '2019-04-21T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 740.2200000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-04-22T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 770.8000000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2019-04-23T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1000.8499999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-04-24T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1016.58,
#   'unit': 'kWh'},
#  {'timestamp': '2019-04-25T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1040.93,
#   'unit': 'kWh'},
#  {'timestamp': '2019-04-26T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1032.8300000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2019-04-27T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 762.03,
#   'unit': 'kWh'},
#  {'timestamp': '2019-04-28T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 753.3399999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-04-29T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 997.1099999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-04-30T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 973.63,
#   'unit': 'kWh'},
#  {'timestamp': '2019-05-01T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 781.89,
#   'unit': 'kWh'},
#  {'timestamp': '2019-05-02T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1018.9899999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2019-05-03T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 992.3099999999997,
#   'unit': 'kWh'},
#  {'timestamp': '2019-05-04T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 749.6899999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2019-05-05T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 749.11,
#   'unit': 'kWh'},
#  {'timestamp': '2019-05-06T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1046.18,
#   'unit': 'kWh'},
#  {'timestamp': '2019-05-07T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1006.95,
#   'unit': 'kWh'},
#  {'timestamp': '2019-05-08T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1010.7599999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-05-09T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1010.9700000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-05-10T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 981.4699999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2019-05-11T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 734.82,
#   'unit': 'kWh'},
#  {'timestamp': '2019-05-12T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 719.7199999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-05-13T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1004.8299999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-05-14T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1019.14,
#   'unit': 'kWh'},
#  {'timestamp': '2019-05-15T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1002.6999999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-05-16T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 978.9900000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-05-17T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 962.5400000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-05-18T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 732.5300000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-05-19T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 740.19,
#   'unit': 'kWh'},
#  {'timestamp': '2019-05-20T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1036.6900000000003,
#   'unit': 'kWh'},
#  {'timestamp': '2019-05-21T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1119.8600000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-05-22T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1003.47,
#   'unit': 'kWh'},
#  {'timestamp': '2019-05-23T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1111.91,
#   'unit': 'kWh'},
#  {'timestamp': '2019-05-24T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1080.39,
#   'unit': 'kWh'},
#  {'timestamp': '2019-05-25T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 778.41,
#   'unit': 'kWh'},
#  {'timestamp': '2019-05-26T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 775.1600000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-05-27T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1000.8399999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-05-28T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 979.2599999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-05-29T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 975.63,
#   'unit': 'kWh'},
#  {'timestamp': '2019-05-30T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 807.5000000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-05-31T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 989.5899999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-06-01T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 782.75,
#   'unit': 'kWh'},
#  {'timestamp': '2019-06-02T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 727.51,
#   'unit': 'kWh'},
#  {'timestamp': '2019-06-03T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 653.38,
#   'unit': 'kWh'},
#  {'timestamp': '2019-06-04T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 546.6999999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-06-05T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 589.73,
#   'unit': 'kWh'},
#  {'timestamp': '2019-06-06T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 611.5200000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-06-07T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 716.69,
#   'unit': 'kWh'},
#  {'timestamp': '2019-06-08T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 365.00000000000006,
#   'unit': 'kWh'},
#  {'timestamp': '2019-06-09T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 364.48,
#   'unit': 'kWh'},
#  {'timestamp': '2019-06-10T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 685.2,
#   'unit': 'kWh'},
#  {'timestamp': '2019-06-11T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 656.2300000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-06-12T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 655.3300000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2019-06-13T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 510.54999999999995,
#   'unit': 'kWh'},
#  {'timestamp': '2019-06-14T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 606.8,
#   'unit': 'kWh'},
#  {'timestamp': '2019-06-15T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 333.91999999999996,
#   'unit': 'kWh'},
#  {'timestamp': '2019-06-16T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 328.86999999999995,
#   'unit': 'kWh'},
#  {'timestamp': '2019-06-17T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 646.68,
#   'unit': 'kWh'},
#  {'timestamp': '2019-06-18T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 654.86,
#   'unit': 'kWh'},
#  {'timestamp': '2019-06-19T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 644.6999999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-06-20T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 645.31,
#   'unit': 'kWh'},
#  {'timestamp': '2019-06-21T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 626.5000000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2019-06-22T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 363.13000000000005,
#   'unit': 'kWh'},
#  {'timestamp': '2019-06-23T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 359.12000000000006,
#   'unit': 'kWh'},
#  {'timestamp': '2019-06-24T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 644.5000000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-06-25T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 636.6500000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2019-06-26T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 634.5800000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2019-06-27T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 606.53,
#   'unit': 'kWh'},
#  {'timestamp': '2019-06-28T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 503.74000000000007,
#   'unit': 'kWh'},
#  {'timestamp': '2019-06-29T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 214.60999999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-06-30T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 310.57999999999987,
#   'unit': 'kWh'},
#  {'timestamp': '2019-07-01T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 600.1700000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-07-02T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 639.2900000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2019-07-03T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 487.43999999999994,
#   'unit': 'kWh'},
#  {'timestamp': '2019-07-04T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 483.69999999999993,
#   'unit': 'kWh'},
#  {'timestamp': '2019-07-05T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 469.86999999999995,
#   'unit': 'kWh'},
#  {'timestamp': '2019-07-06T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 194.4,
#   'unit': 'kWh'},
#  {'timestamp': '2019-07-07T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 261.57000000000005,
#   'unit': 'kWh'},
#  {'timestamp': '2019-07-08T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 559.49,
#   'unit': 'kWh'},
#  {'timestamp': '2019-07-09T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 478.58999999999986,
#   'unit': 'kWh'},
#  {'timestamp': '2019-07-10T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 459.73999999999984,
#   'unit': 'kWh'},
#  {'timestamp': '2019-07-11T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 534.6500000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-07-12T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 439.56999999999994,
#   'unit': 'kWh'},
#  {'timestamp': '2019-07-13T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 207.11,
#   'unit': 'kWh'},
#  {'timestamp': '2019-07-14T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 266.87,
#   'unit': 'kWh'},
#  {'timestamp': '2019-07-15T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 577.04,
#   'unit': 'kWh'},
#  {'timestamp': '2019-07-16T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 538.7499999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-07-17T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 473.72,
#   'unit': 'kWh'},
#  {'timestamp': '2019-07-18T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 574.4999999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-07-19T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 603.97,
#   'unit': 'kWh'},
#  {'timestamp': '2019-07-20T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 356.78,
#   'unit': 'kWh'},
#  {'timestamp': '2019-07-21T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 357.80000000000007,
#   'unit': 'kWh'},
#  {'timestamp': '2019-07-22T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 643.2799999999997,
#   'unit': 'kWh'},
#  {'timestamp': '2019-07-23T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 641.0199999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-07-24T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 648.9900000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-07-25T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 644.66,
#   'unit': 'kWh'},
#  {'timestamp': '2019-07-26T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 625.0599999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2019-07-27T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 355.27,
#   'unit': 'kWh'},
#  {'timestamp': '2019-07-28T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 363.94,
#   'unit': 'kWh'},
#  {'timestamp': '2019-07-29T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 657.7499999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-07-30T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 664.6100000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2019-07-31T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 508.4199999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-08-01T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 647.7600000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-08-02T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 565.7600000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2019-08-03T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 248.94,
#   'unit': 'kWh'},
#  {'timestamp': '2019-08-04T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 195.66000000000005,
#   'unit': 'kWh'},
#  {'timestamp': '2019-08-05T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 537.4799999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-08-06T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 670.6500000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-08-07T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 706.99,
#   'unit': 'kWh'},
#  {'timestamp': '2019-08-08T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 826.3699999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-08-09T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 853.0,
#   'unit': 'kWh'},
#  {'timestamp': '2019-08-10T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 350.3699999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-08-11T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 400.5899999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-08-12T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 905.15,
#   'unit': 'kWh'},
#  {'timestamp': '2019-08-13T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 923.23,
#   'unit': 'kWh'},
#  {'timestamp': '2019-08-14T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 858.9999999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2019-08-15T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 874.7700000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-08-16T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 866.36,
#   'unit': 'kWh'},
#  {'timestamp': '2019-08-17T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 355.0,
#   'unit': 'kWh'},
#  {'timestamp': '2019-08-18T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 397.97,
#   'unit': 'kWh'},
#  {'timestamp': '2019-08-19T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 901.07,
#   'unit': 'kWh'},
#  {'timestamp': '2019-08-20T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 898.24,
#   'unit': 'kWh'},
#  {'timestamp': '2019-08-21T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 931.8399999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-08-22T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 906.3399999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-08-23T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 904.6800000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-08-24T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 360.0599999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-08-25T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 386.90999999999997,
#   'unit': 'kWh'},
#  {'timestamp': '2019-08-26T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 927.54,
#   'unit': 'kWh'},
#  {'timestamp': '2019-08-27T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1032.79,
#   'unit': 'kWh'},
#  {'timestamp': '2019-08-28T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1069.4,
#   'unit': 'kWh'},
#  {'timestamp': '2019-08-29T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1073.48,
#   'unit': 'kWh'},
#  {'timestamp': '2019-08-30T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1049.43,
#   'unit': 'kWh'},
#  {'timestamp': '2019-08-31T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 744.5799999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-09-01T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 742.06,
#   'unit': 'kWh'},
#  {'timestamp': '2019-09-02T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1041.27,
#   'unit': 'kWh'},
#  {'timestamp': '2019-09-03T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1098.04,
#   'unit': 'kWh'},
#  {'timestamp': '2019-09-04T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1108.1699999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2019-09-05T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1087.8500000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-09-06T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1106.27,
#   'unit': 'kWh'},
#  {'timestamp': '2019-09-07T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 778.86,
#   'unit': 'kWh'},
#  {'timestamp': '2019-09-08T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 735.9799999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-09-09T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1042.72,
#   'unit': 'kWh'},
#  {'timestamp': '2019-09-10T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1009.0899999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2019-09-11T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1058.1799999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2019-09-12T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1024.4099999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-09-13T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 1014.7300000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-09-14T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 713.56,
#   'unit': 'kWh'},
#  {'timestamp': '2019-09-15T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 709.15,
#   'unit': 'kWh'},
#  {'timestamp': '2019-09-16T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 994.27,
#   'unit': 'kWh'},
#  {'timestamp': '2019-09-17T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 984.5300000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-09-18T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 991.9199999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2019-09-19T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 975.2399999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-09-20T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 967.0400000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-09-21T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 690.2,
#   'unit': 'kWh'},
#  {'timestamp': '2019-09-22T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 681.53,
#   'unit': 'kWh'},
#  {'timestamp': '2019-09-23T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 974.9300000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-09-24T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 992.21,
#   'unit': 'kWh'},
#  {'timestamp': '2019-09-25T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 960.6999999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2019-09-26T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 717.39,
#   'unit': 'kWh'},
#  {'timestamp': '2019-09-27T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 714.5399999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2019-09-28T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 226.16,
#   'unit': 'kWh'},
#  {'timestamp': '2019-09-29T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 226.88,
#   'unit': 'kWh'},
#  {'timestamp': '2019-09-30T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 742.2299999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-10-01T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 728.8600000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2019-10-02T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 726.3399999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-10-03T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 737.7,
#   'unit': 'kWh'},
#  {'timestamp': '2019-10-04T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 718.8400000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-10-05T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 222.84999999999997,
#   'unit': 'kWh'},
#  {'timestamp': '2019-10-06T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 228.86000000000004,
#   'unit': 'kWh'},
#  {'timestamp': '2019-10-07T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 728.03,
#   'unit': 'kWh'},
#  {'timestamp': '2019-10-08T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 722.91,
#   'unit': 'kWh'},
#  {'timestamp': '2019-10-09T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 698.4200000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2019-10-10T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 743.53,
#   'unit': 'kWh'},
#  {'timestamp': '2019-10-11T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 730.0499999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2019-10-12T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 230.68,
#   'unit': 'kWh'},
#  {'timestamp': '2019-10-13T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 225.87000000000006,
#   'unit': 'kWh'},
#  {'timestamp': '2019-10-14T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 499.87,
#   'unit': 'kWh'},
#  {'timestamp': '2019-10-15T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 491.25000000000006,
#   'unit': 'kWh'},
#  {'timestamp': '2019-10-16T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 476.37999999999994,
#   'unit': 'kWh'},
#  {'timestamp': '2019-10-17T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 479.84,
#   'unit': 'kWh'},
#  {'timestamp': '2019-10-18T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 476.6499999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2019-10-19T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 221.56,
#   'unit': 'kWh'},
#  {'timestamp': '2019-10-20T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 222.53999999999996,
#   'unit': 'kWh'},
#  {'timestamp': '2019-10-21T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 748.1100000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-10-22T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 723.66,
#   'unit': 'kWh'},
#  {'timestamp': '2019-10-23T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 714.9000000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2019-10-24T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 731.01,
#   'unit': 'kWh'},
#  {'timestamp': '2019-10-25T00:00:00',
# ...
#   'value': 632.7,
#   'unit': 'kWh'},
#  {'timestamp': '2021-06-26T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 357.63,
#   'unit': 'kWh'},
#  {'timestamp': '2021-06-27T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 476.28000000000003,
#   'unit': 'kWh'},
#  {'timestamp': '2021-06-28T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 666.3300000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2021-06-29T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 643.58,
#   'unit': 'kWh'},
#  {'timestamp': '2021-06-30T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 645.5000000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2021-07-01T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 636.8,
#   'unit': 'kWh'},
#  {'timestamp': '2021-07-02T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 632.4,
#   'unit': 'kWh'},
#  {'timestamp': '2021-07-03T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 355.3399999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2021-07-04T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 472.70000000000005,
#   'unit': 'kWh'},
#  {'timestamp': '2021-07-05T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 651.03,
#   'unit': 'kWh'},
#  {'timestamp': '2021-07-06T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 631.7000000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2021-07-07T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 632.6700000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2021-07-08T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 629.69,
#   'unit': 'kWh'},
#  {'timestamp': '2021-07-09T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 624.3900000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2021-07-10T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 354.34,
#   'unit': 'kWh'},
#  {'timestamp': '2021-07-11T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 470.6300000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2021-07-12T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 642.2699999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2021-07-13T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 628.15,
#   'unit': 'kWh'},
#  {'timestamp': '2021-07-14T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 623.74,
#   'unit': 'kWh'},
#  {'timestamp': '2021-07-15T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 618.2799999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2021-07-16T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 618.2200000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2021-07-17T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 344.51,
#   'unit': 'kWh'},
#  {'timestamp': '2021-07-18T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 463.5299999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2021-07-19T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 632.1300000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2021-07-20T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 619.0699999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2021-07-21T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 620.51,
#   'unit': 'kWh'},
#  {'timestamp': '2021-07-22T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 613.9,
#   'unit': 'kWh'},
#  {'timestamp': '2021-07-23T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 613.6699999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2021-07-24T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 347.55,
#   'unit': 'kWh'},
#  {'timestamp': '2021-07-25T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 340.83000000000015,
#   'unit': 'kWh'},
#  {'timestamp': '2021-07-26T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 620.1600000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2021-07-27T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 610.4600000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2021-07-28T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 621.38,
#   'unit': 'kWh'},
#  {'timestamp': '2021-07-29T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 622.0400000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2021-07-30T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 640.1299999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2021-07-31T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 353.35999999999996,
#   'unit': 'kWh'},
#  {'timestamp': '2021-08-01T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 348.94999999999993,
#   'unit': 'kWh'},
#  {'timestamp': '2021-08-02T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 637.7400000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2021-08-03T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 638.3200000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2021-08-04T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 558.7500000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2021-08-05T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 543.5999999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2021-08-06T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 570.9899999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2021-08-07T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 285.12000000000006,
#   'unit': 'kWh'},
#  {'timestamp': '2021-08-08T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 297.50999999999993,
#   'unit': 'kWh'},
#  {'timestamp': '2021-08-09T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 717.8900000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2021-08-10T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 679.9000000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2021-08-11T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 798.4899999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2021-08-12T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 812.7500000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2021-08-13T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 783.8299999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2021-08-14T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 366.36999999999995,
#   'unit': 'kWh'},
#  {'timestamp': '2021-08-15T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 355.22,
#   'unit': 'kWh'},
#  {'timestamp': '2021-08-16T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 811.6599999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2021-08-17T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 836.9699999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2021-08-18T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 843.4299999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2021-08-19T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 869.55,
#   'unit': 'kWh'},
#  {'timestamp': '2021-08-20T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 778.5799999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2021-08-21T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 317.66999999999996,
#   'unit': 'kWh'},
#  {'timestamp': '2021-08-22T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 313.68,
#   'unit': 'kWh'},
#  {'timestamp': '2021-08-23T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 751.51,
#   'unit': 'kWh'},
#  {'timestamp': '2021-08-24T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 743.42,
#   'unit': 'kWh'},
#  {'timestamp': '2021-08-25T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 771.79,
#   'unit': 'kWh'},
#  {'timestamp': '2021-08-26T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 762.55,
#   'unit': 'kWh'},
#  {'timestamp': '2021-08-27T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 763.4499999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2021-08-28T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 309.42,
#   'unit': 'kWh'},
#  {'timestamp': '2021-08-29T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 305.27,
#   'unit': 'kWh'},
#  {'timestamp': '2021-08-30T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 790.19,
#   'unit': 'kWh'},
#  {'timestamp': '2021-08-31T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 792.4900000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2021-09-01T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 756.26,
#   'unit': 'kWh'},
#  {'timestamp': '2021-09-02T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 770.12,
#   'unit': 'kWh'},
#  {'timestamp': '2021-09-03T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 750.27,
#   'unit': 'kWh'},
#  {'timestamp': '2021-09-04T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 219.33999999999995,
#   'unit': 'kWh'},
#  {'timestamp': '2021-09-05T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 219.45999999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2021-09-06T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 755.37,
#   'unit': 'kWh'},
#  {'timestamp': '2021-09-07T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 767.9299999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2021-09-08T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 761.9,
#   'unit': 'kWh'},
#  {'timestamp': '2021-09-09T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 774.5599999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2021-09-10T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 728.8799999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2021-09-11T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 224.52999999999997,
#   'unit': 'kWh'},
#  {'timestamp': '2021-09-12T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 238.71999999999997,
#   'unit': 'kWh'},
#  {'timestamp': '2021-09-13T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 784.2099999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2021-09-14T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 748.7800000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2021-09-15T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 752.2399999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2021-09-16T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 749.0100000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2021-09-17T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 731.24,
#   'unit': 'kWh'},
#  {'timestamp': '2021-09-18T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 239.69000000000003,
#   'unit': 'kWh'},
#  {'timestamp': '2021-09-19T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 235.12,
#   'unit': 'kWh'},
#  {'timestamp': '2021-09-20T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 758.3199999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2021-09-21T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 742.9600000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2021-09-22T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 745.3699999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2021-09-23T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 811.9,
#   'unit': 'kWh'},
#  {'timestamp': '2021-09-24T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 760.7299999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2021-09-25T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 247.22,
#   'unit': 'kWh'},
#  {'timestamp': '2021-09-26T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 223.4,
#   'unit': 'kWh'},
#  {'timestamp': '2021-09-27T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 750.6200000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2021-09-28T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 761.0100000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2021-09-29T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 761.9399999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2021-09-30T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '4285 Kaisaniemen ala-aste',
#   'value': 764.1400000000002,
#   'unit': 'kWh'},
#  ...]

# %%
# A simple code for the acquisition of necessary datasets from NUUKA API

def toDatetime(record):

    timestamp = record['timestamp']
    record['timestamp'] = datetime.strptime(timestamp, "%Y-%m-%dT%H:%M:%S")
    return record

def getData(startTime, endTime , freq="Daily"):
    
    reportingGroups = ["Electricity"]
    #reportingGroups = ["Heat"]
    #reportingGroups = ["Water"]
    #reportingGroups = ["DistrictCooling"]
    
    locationsLink = 'https://helsinki-openapi.nuuka.cloud/api/v1.0/Property/List'
    
    # Initialize api
    locationsRequest = requests.get(locationsLink) 
    # Get data from api
    locationsRequest.raise_for_status() 
    locations = pd.DataFrame.from_dict(locationsRequest.json())
    locations = locations['locationName']
    data = []
    dataLink = (f"https://helsinki-openapi.nuuka.cloud/api/v1.0/"
                f"EnergyData/{freq}/ListByProperty")
          
    # Helper function for concurrency 
    def request(group, location):
        payload = {'StartTime': startTime, 'EndTime': endTime}
        payload.update({'ReportingGroup': group})
        payload.update({'SearchString': location.split(' ', 1)[0]})
        r = requests.get(dataLink, payload)
        if r.status_code == requests.codes.ok:
            data_dict = r.json()
            for record in data_dict:
                toDatetime(record)
            data.extend(data_dict)
    
    # The final step - getting the data.
    for g in reportingGroups:
        with concurrent.futures.ThreadPoolExecutor() as executor:
            executor.map(partial(request, g), locations)
            
    # For each "thread", execute "request" function on each location
    return pd.DataFrame(data)

# %% [markdown]
# ### Save data to a local .csv file

# %%
# Request the data from the API.
start = time.perf_counter()
ts = getData('2019-01-01', '2021-12-31', freq = 'Daily') 
finish = time.perf_counter()
print(f'Finished in {finish-start} second(s)')

# Export the dataframe to a .csv file
file_name = 'Helsinki_all_daily.csv' # change this to the respective frequency of the data
ts.to_csv(file_name)
# Out:
# Finished in 98.63750589999836 second(s)

# %%
dataset=pd.read_csv('Helsinki_all_daily.csv')

# %%
#Please pay attention to the .csv document where IDs can change time to time due to the API updates
df2 = dataset.iloc[345316:346406]

# %%
df2.rename(columns = {'value':'ElCons', 'timestamp':'Date'}, inplace = True)
df2.index = df2.Date
df2=df2.drop(['Date'],axis=1)

# %%
df2
# Out:
#             Unnamed: 0 reportingGroup               locationName  ElCons unit
# Date
# 2019-01-01      345316    Electricity  4285 Kaisaniemen ala-aste  799.86  kWh
# 2019-01-02      345317    Electricity  4285 Kaisaniemen ala-aste  787.14  kWh
# 2019-01-03      345318    Electricity  4285 Kaisaniemen ala-aste  696.91  kWh
# 2019-01-04      345319    Electricity  4285 Kaisaniemen ala-aste  789.18  kWh
# 2019-01-05      345320    Electricity  4285 Kaisaniemen ala-aste  677.54  kWh
# ...                ...            ...                        ...     ...  ...
# 2021-12-26      346401    Electricity  4285 Kaisaniemen ala-aste  258.54  kWh
# 2021-12-27      346402    Electricity  4285 Kaisaniemen ala-aste  540.82  kWh
# 2021-12-28      346403    Electricity  4285 Kaisaniemen ala-aste  526.72  kWh
# 2021-12-29      346404    Electricity  4285 Kaisaniemen ala-aste  523.42  kWh
# 2021-12-30      346405    Electricity  4285 Kaisaniemen ala-aste  522.32  kWh
#
# [1090 rows x 5 columns]

# %%
df2=df2.drop(columns=['Unnamed: 0','reportingGroup','locationName','unit'])

# %%
df2.rename(columns = {'value':'ElCons'}, inplace = True)

# %%
df2
# Out:
#             ElCons
# Date
# 2019-01-01  799.86
# 2019-01-02  787.14
# 2019-01-03  696.91
# 2019-01-04  789.18
# 2019-01-05  677.54
# ...            ...
# 2021-12-26  258.54
# 2021-12-27  540.82
# 2021-12-28  526.72
# 2021-12-29  523.42
# 2021-12-30  522.32
#
# [1090 rows x 1 columns]

# %%
# Save a file with daily electricity consumption data

#df2.to_csv('kaisa_dailyElCons.csv')

# %% [markdown]
# Weather data can be downloaded manually from https://en.ilmatieteenlaitos.fi/download-observations
